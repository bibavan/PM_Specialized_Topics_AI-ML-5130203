# %% [markdown]
# # Metadata on Parkinson's disease dataset
#
# - **Age**: The age of the patients ranges from 50 to 90 years.
# - **Gender**: Gender of the patients, where 0 represents Male and 1 represents Female.
# - **Ethnicity**: The ethnicity of the patients, coded as follows:
#     - 0: Caucasian
#     - 1: African American
#     - 2: Asian
#     - 3: Other
# - **EducationLevel**: The education level of the patients, coded as follows:
#     - 0: None
#     - 1: High School
#     - 2: Bachelor's
#     - 3: Higher
# - **BMI**: Body Mass Index of the patients, ranging from 15 to 40.
# - **Smoking**: Smoking status, where 0 indicates No and 1 indicates Yes.
# - **AlcoholConsumption**: Weekly alcohol consumption in units, ranging from 0 to 20.
# - **PhysicalActivity**: Weekly physical activity in hours, ranging from 0 to 10.
# - **DietQuality**: Diet quality score, ranging from 0 to 10.
# - **SleepQuality**: Sleep quality score, ranging from 4 to 10.
# - **FamilyHistoryParkinsons**: Family history of Parkinson's Disease, where 0 indicates No and 1 indicates Yes.
# - **TraumaticBrainInjury**: History of traumatic brain injury, where 0 indicates No and 1 indicates Yes.
# - **Hypertension**: Presence of hypertension, where 0 indicates No and 1 indicates Yes.
# - **Diabetes**: Presence of diabetes, where 0 indicates No and 1 indicates Yes.
# - **Depression**: Presence of depression, where 0 indicates No and 1 indicates Yes.
# - **Stroke**: History of stroke, where 0 indicates No and 1 indicates Yes.
# - **SystolicBP**: Systolic blood pressure, ranging from 90 to 180 mmHg.
# - **DiastolicBP**: Diastolic blood pressure, ranging from 60 to 120 mmHg.
# - **CholesterolTotal**: Total cholesterol levels, ranging from 150 to 300 mg/dL.
# - **CholesterolLDL**: Low-density lipoprotein cholesterol levels, ranging from 50 to 200 mg/dL.
# - **CholesterolHDL**: High-density lipoprotein cholesterol levels, ranging from 20 to 100 mg/dL.
# - **CholesterolTriglycerides**: Triglycerides levels, ranging from 50 to 400 mg/dL.
# - **UPDRS**: Unified Parkinson's Disease Rating Scale score, ranging from 0 to 199. Higher scores indicate greater severity of the disease.
# - **MoCA**: Montreal Cognitive Assessment score, ranging from 0 to 30. Lower scores indicate cognitive impairment.
# - **FunctionalAssessment**: Functional assessment score, ranging from 0 to 10. Lower scores indicate greater impairment.
# - **Tremor**: Presence of tremor, where 0 indicates No and 1 indicates Yes.
# - **Rigidity**: Presence of muscle rigidity, where 0 indicates No and 1 indicates Yes.
# - **Bradykinesia**: Presence of bradykinesia (slowness of movement), where 0 indicates No and 1 indicates Yes.
# - **PosturalInstability**: Presence of postural instability, where 0 indicates No and 1 indicates Yes.
# - **SpeechProblems**: Presence of speech problems, where 0 indicates No and 1 indicates Yes.
# - **SleepDisorders**: Presence of sleep disorders, where 0 indicates No and 1 indicates Yes.
# - **Constipation**: Presence of constipation, where 0 indicates No and 1 indicates Yes.
# - **Diagnosis**: Diagnosis status for Parkinson's Disease, where 0 indicates No and 1 indicates Yes.

# %%
# import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
dataset = pd.read_csv("dataset/parkinsons_disease_data.csv", sep = ",", skipinitialspace=True)
dataset.columns
dataset.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0       3058   85       0          3               1  19.619878        0
# 1       3059   75       0          0               2  16.247339        1
# 2       3060   70       1          0               0  15.368239        0
# 3       3061   52       0          0               0  15.454557        0
# 4       3062   87       0          0               1  18.616042        0
#
#    AlcoholConsumption  PhysicalActivity  DietQuality  ...  \
# 0            5.108241          1.380660     3.893969  ...
# 1            6.027648          8.409804     8.513428  ...
# 2            2.242135          0.213275     6.498805  ...
# 3            5.997788          1.375045     6.715033  ...
# 4            9.775243          1.188607     4.657572  ...
#
#    FunctionalAssessment  Tremor  Rigidity  Bradykinesia  PosturalInstability  \
# 0              1.572427       1         0             0                    0
# ...

# %%
# print important information about dataset
print("#Total of samples = ", dataset.shape[0])
print("#Features = ", dataset.shape[1])
# Out:
# #Total of samples =  2105
# #Features =  35

# %%
# checking the missing values
print(dataset.isnull().sum())
dataset[dataset.eq("?").any(axis=1)].head()
# Out:
# PatientID                   0
# Age                         0
# Gender                      0
# Ethnicity                   0
# EducationLevel              0
# BMI                         0
# Smoking                     0
# AlcoholConsumption          0
# PhysicalActivity            0
# DietQuality                 0
# SleepQuality                0
# FamilyHistoryParkinsons     0
# TraumaticBrainInjury        0
# Hypertension                0
# Diabetes                    0
# Depression                  0
# Stroke                      0
# SystolicBP                  0
# DiastolicBP                 0
# CholesterolTotal            0
# CholesterolLDL              0
# CholesterolHDL              0
# CholesterolTriglycerides    0
# UPDRS                       0
# MoCA                        0
# FunctionalAssessment        0
# Tremor                      0
# Rigidity                    0
# Bradykinesia                0
# PosturalInstability         0
# SpeechProblems              0
# ...

# %%
# plot missing data
sbn.displot(
    data = dataset.isna().melt(value_name="missing"),
    y = "variable",
    hue = "missing",
    multiple = "fill",
    aspect = 1.5
)

plt.show()

# %% [raw]
# There is no missing data.

# %%
dataset = dataset.dropna()
print("#Total samples without missing values = ", len(dataset))
# Out:
# #Total samples without missing values =  2105

# %%
dataset.columns
# Out:
# Index(['PatientID', 'Age', 'Gender', 'Ethnicity', 'EducationLevel', 'BMI',
#        'Smoking', 'AlcoholConsumption', 'PhysicalActivity', 'DietQuality',
#        'SleepQuality', 'FamilyHistoryParkinsons', 'TraumaticBrainInjury',
#        'Hypertension', 'Diabetes', 'Depression', 'Stroke', 'SystolicBP',
#        'DiastolicBP', 'CholesterolTotal', 'CholesterolLDL', 'CholesterolHDL',
#        'CholesterolTriglycerides', 'UPDRS', 'MoCA', 'FunctionalAssessment',
#        'Tremor', 'Rigidity', 'Bradykinesia', 'PosturalInstability',
#        'SpeechProblems', 'SleepDisorders', 'Constipation', 'Diagnosis',
#        'DoctorInCharge'],
#       dtype='object')

# %%
numerical_cols =  ['Age','BMI','AlcoholConsumption', 'PhysicalActivity', 'DietQuality',
       'SleepQuality', 'SystolicBP', 'DiastolicBP', 'CholesterolTotal', 'CholesterolLDL', 'CholesterolHDL',
       'CholesterolTriglycerides', 'UPDRS', 'MoCA', 'FunctionalAssessment', 'Diagnosis']

# %%
dataset.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0       3058   85       0          3               1  19.619878        0
# 1       3059   75       0          0               2  16.247339        1
# 2       3060   70       1          0               0  15.368239        0
# 3       3061   52       0          0               0  15.454557        0
# 4       3062   87       0          0               1  18.616042        0
#
#    AlcoholConsumption  PhysicalActivity  DietQuality  ...  \
# 0            5.108241          1.380660     3.893969  ...
# 1            6.027648          8.409804     8.513428  ...
# 2            2.242135          0.213275     6.498805  ...
# 3            5.997788          1.375045     6.715033  ...
# 4            9.775243          1.188607     4.657572  ...
#
#    FunctionalAssessment  Tremor  Rigidity  Bradykinesia  PosturalInstability  \
# 0              1.572427       1         0             0                    0
# ...

# %%
# function to plot distribution for 1 numerical column
def hist_frequencies(data, column, bins):
    sbn.histplot(data[column], color = "blue", bins = bins)
    plt.xlabel(column)
    plt.ylabel("Frequencies")
    plt.title("Histogram distribution for " + column)
    plt.show()

# %%
# plot the distribution for each numerical column
for col in numerical_cols:
    hist_frequencies(dataset, col, 10)

# %% [markdown]
# - **Age**: The patients' ages range from 50 to 89 years, with an average of 69.6 years and a standard deviation of 11.6 years.
# - **BMI**: The Body Mass Index ranges from 15.01 to 40, with an average BMI of 27.21 and a standard deviation of 7.21.
# - **AlcoholConsumption**: Weekly alcohol consumption varies widely, ranging from 0 to 20 units, with an average of 10.04 units.
# - **PhysicalActivity**: The patients engage in between 0 to 10 hours of weekly physical activity, with an average of 5.02 hours.
# - **DietQuality**: Diet quality scores range from 0 to 10, with an average score of 4.91.
# - **SleepQuality**: Sleep quality scores range from 4 to 10, with an average score of 7.00.
# - **SystolicBP & DiastolicBP**: Systolic blood pressure ranges from 90 to 180 mmHg, while diastolic blood pressure ranges from 60 to 120 mmHg.
# - **Cholesterol Levels**: Total cholesterol levels range from 150 to 300 mg/dL. LDL, HDL, and triglycerides levels vary widely.
# - **UPDRS**: Unified Parkinson's Disease Rating Scale scores range from 0 to 199, indicating varying degrees of disease severity.
# - **MoCA**: Montreal Cognitive Assessment scores range from 0 to 30, with an average score of 15.09, indicating varying levels of cognitive function.
# - **Diagnosis**: 61.9% of the patients have been diagnosed with Parkinson's Disease.

# %%
# function to plot distribution for 1 numerical column
def hist_density(data, column, bins):
    sbn.histplot(data[column], color = "blue", bins = bins, kde = False, stat = "density", alpha = 0.5)
    sbn.kdeplot(data[column], color = "red", linewidth = 2)
    plt.xlabel(column)
    plt.ylabel("Density")
    plt.title("Histogram and KDE for " + column)    
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# %%
# plot the distribution for each numerical column
for col in numerical_cols:
    hist_density(dataset, col, 10)

# %%
# function to make boxplot
def statistics_nvar(data, numerical_cols):
    # calculate the nrows and ncols for plots
    ncol_plots = 3
    nrow_plots = (len(numerical_cols) + ncol_plots - 1) // ncol_plots
    # create the subplots for specific row and column
    fig, axs = plt.subplots(nrow_plots, ncol_plots, figsize = (16, 4 * nrow_plots))
    axs = axs.flatten()
    # create boxplots for each numerical column
    for i, col in enumerate(numerical_cols):
        sbn.boxplot(data[col], ax = axs[i])
        axs[i].set_title("Box plot for " + col)
    plt.tight_layout()
    plt.show()

# %%
# boxplot for each numerical column
statistics_nvar(filtered_dataset, numerical_cols)

# %%
# statistical information about numerical variables
dataset[numerical_cols].describe()
# Out:
#                Age          BMI  AlcoholConsumption  PhysicalActivity  \
# count  2105.000000  2105.000000         2105.000000       2105.000000
# mean     69.601900    27.209493           10.040413          5.016674
# std      11.594511     7.208099            5.687014          2.890919
# min      50.000000    15.008333            0.002228          0.004157
# 25%      60.000000    20.782176            5.150278          2.455703
# 50%      70.000000    27.184571           10.070337          5.031550
# 75%      80.000000    33.462452           14.829565          7.512795
# max      89.000000    39.999887           19.988866          9.995255
#
#        DietQuality  SleepQuality   SystolicBP  DiastolicBP  CholesterolTotal  \
# count  2105.000000   2105.000000  2105.000000  2105.000000       2105.000000
# mean      4.912901      6.996639   133.719715    90.249881        226.860840
# std       2.872115      1.753065    26.502355    17.061488         43.589406
# ...

# %%
def plot_correlation2(data, cols):
    # Корреляционная матрица
    corr = data[cols].corr()
    
    # Построение тепловой карты
    plt.figure(figsize=(10, 8))
    sbn.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f", square=True)
    plt.title("Correlation Analysis")
    plt.show()

# %%
plot_correlation2(dataset, numerical_cols)

# %% [markdown]
# - There is a slight correlation of the correct diagnosis on age,
# this is logical, since Parkinson's disease is increasingly common in older people.
# here is also a correlation of the diagnosis on URDRS.
#
# - Otherwise, there are no strong correlations, which tells us that Parkinson's disease is quite difficult to diagnose correctly, and the symptoms that manifest in it can also manifest in the presence of other diseases.

# %%
from scipy import stats

# Function for outliers detection based on percentiles
def outliers_detection(dataset, col, lower_percentile=2.275, upper_percentile=97.725):
    # Calculate the percentiles
    lower_bound = dataset[col].quantile(lower_percentile / 100)
    upper_bound = dataset[col].quantile(upper_percentile / 100)
    
    # Filter out the outliers
    outliers = dataset[(dataset[col] < lower_bound) | (dataset[col] > upper_bound)]
    
    return outliers

# %%
# cycle to check the number of outliers in each numerical column
for col in numerical_cols:
    print("\n*** Outliers detection in " + col + " ***")
    lst_outliers = outliers_detection(dataset, col)
    print(f"#samples outlier to distribution = {len(lst_outliers)}")
    print(f"%outliers = {round(100* len(lst_outliers)/len(dataset), 2)} %")
# Out:
# *** Outliers detection in Age ***
# #samples outlier to distribution = 0
# %outliers = 0.0 %
#
# *** Outliers detection in BMI ***
# #samples outlier to distribution = 96
# %outliers = 4.56 %
#
# *** Outliers detection in AlcoholConsumption ***
# #samples outlier to distribution = 96
# %outliers = 4.56 %
#
# *** Outliers detection in PhysicalActivity ***
# #samples outlier to distribution = 96
# %outliers = 4.56 %
#
# *** Outliers detection in DietQuality ***
# #samples outlier to distribution = 96
# %outliers = 4.56 %
#
# *** Outliers detection in SleepQuality ***
# #samples outlier to distribution = 96
# %outliers = 4.56 %
#
# *** Outliers detection in SystolicBP ***
# #samples outlier to distribution = 92
# %outliers = 4.37 %
#
# *** Outliers detection in DiastolicBP ***
# #samples outlier to distribution = 74
# %outliers = 3.52 %
#
# *** Outliers detection in CholesterolTotal ***
# #samples outlier to distribution = 96
# %outliers = 4.56 %
#
# ...

# %%
# list of categorical variables
# stress_relief_activities should be proccesed alone, beacuse it is bacically an array of data
categorical_vars = list(set(dataset.columns) - set(numerical_cols))
categorical_vars
# Out:
# ['EducationLevel',
#  'Stroke',
#  'Hypertension',
#  'PosturalInstability',
#  'Ethnicity',
#  'Smoking',
#  'DoctorInCharge',
#  'SpeechProblems',
#  'PatientID',
#  'Constipation',
#  'SleepDisorders',
#  'FamilyHistoryParkinsons',
#  'Gender',
#  'TraumaticBrainInjury',
#  'Bradykinesia',
#  'Depression',
#  'Rigidity',
#  'Diabetes',
#  'Tremor']

# %%
# cycle to calculate number of instances in each categorical column
for col in categorical_vars:
    print("\n***** " + col + " ******")
    print(dataset[col].value_counts())
# Out:
# ***** EducationLevel ******
# EducationLevel
# 1    840
# 2    656
# 0    388
# 3    221
# Name: count, dtype: int64
#
# ***** Stroke ******
# Stroke
# 0    2002
# 1     103
# Name: count, dtype: int64
#
# ***** Hypertension ******
# Hypertension
# 0    1798
# 1     307
# Name: count, dtype: int64
#
# ***** PosturalInstability ******
# PosturalInstability
# 0    1813
# 1     292
# Name: count, dtype: int64
#
# ***** Ethnicity ******
# Ethnicity
# 0    1270
# 1     425
# 3     213
# 2     197
# Name: count, dtype: int64
#
# ***** Smoking ******
# Smoking
# 0    1481
# 1     624
# Name: count, dtype: int64
#
# ***** DoctorInCharge ******
# DoctorInCharge
# DrXXXConfid    2105
# Name: count, dtype: int64
#
# ***** SpeechProblems ******
# SpeechProblems
# 0    1484
# 1     621
# Name: count, dtype: int64
#
# ***** PatientID ******
# PatientID
# 3058    1
# 4472    1
# 4470    1
# 4469    1
# 4468    1
#        ..
# 3755    1
# 3754    1
# 3753    1
# 3752    1
# 5162    1
# ...

# %%
# function to plot bar chart for absolute frequencies in 1 categorical column
def plot_barchart(dataset, col):
    results = dataset[col].value_counts()
    sbn.barplot(x = results.values.tolist(), y = results.index.tolist(), orient = "y")
    plt.title("Statistical analysis by " + col)
    plt.show()

# %%
# cycle to plot bar chart for each categorical column
for col in categorical_vars:
    plot_barchart(dataset, col)

# %% [markdown]
# - **Ethnicity**: The majority of patients belong to ethnicity category 0 (Caucasian), with ethnicity values ranging from 0 to 3.
# - **EducationLevel**: The education level ranges from 0 (none) to 3 (higher education), with an average level of 1.34, where 1 stand for Highschool
# - **Smoking**: About 29.6% of the patients report smoking.
# - **FamilyHistoryParkinsons**: Only 14.6% of the patients have a family history of Parkinson's Disease.
# - **Tremor, Rigidity, Bradykinesia, PosturalInstability, SpeechProblems, Depression**: These are binary variables (0 = no, 1 = yes) representing the presence of specific symptoms. For example, 43.2% of patients experience tremor.

# %%
# function to plot pie chart for relative frequencies in 1 categorical column
def plot_piechart(dataset, col):
    # count the #samples for each categogy
    results = dataset[col].value_counts()
    # calculate the relative frequencies
    total_samples = results.sum()
    rel_freq = results/total_samples
    sbn.set_style("whitegrid")
    plt.figure(figsize=(6,6))
    plt.pie(rel_freq.values.tolist(), labels = rel_freq.index.tolist(), autopct='%1.1f%%')
    plt.title("Relative frequency analysis by " + col)
    plt.show()

# %%
# cycle to plot pie chart for each categorical column
for col in categorical_vars:
    plot_piechart(dataset, col)

# %% [markdown]
# - These pie charts present the same information as the earlier graphs, but represent it in percentage form. It is evident that in most charts, the data is distributed fairly evenly
